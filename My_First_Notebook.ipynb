# %% [markdown]
# <a href="https://colab.research.google.com/github/teachercamila1997-bit/jupyter-exploration/blob/main/My_First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My First Jupyter Notebook
#
# This is my first Markdown cell in Jupyter. In this notebook, I am practicing how to create and run Markdown and Python code cells.

# %%
print("Hello, World!")
# Out:
# Hello, World!
